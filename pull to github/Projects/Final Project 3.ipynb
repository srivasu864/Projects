# %%
#EDA For Restaurant's Cuisine Ratings Data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('C:\\vas.12344\\Cuisine_rating.csv')
df.describe()
#df.info()
#df['User ID'],df['Area code'],df['Location'],df['Gender'],df['YOB'],df['Marital Status']
#df['Activity'],df['Budget'],df['Cuisines'],df['Alcohol'],df['Smoker'],df['Food Rating']
#df['Service Rating'],df['Overall Rating'],df['Often A S']
df['Area code'].value_counts()
df['Area code'].unique()
#df.isna().sum()
h_ac=sns.histplot(df['Area code'])
#---------------------------------------->
df['Location'].unique()
a=np.array(df['Location'])
#df['Location'].value_counts()
h_l=sns.histplot(df['Location'])
#--------------------------------------->
h_g=sns.histplot(df['Gender'])
#--------------------------------------->
df['YOB'].unique()
#1955-->old,new<-----2007
df['YOB'].value_counts()
h_yob=sns.histplot(df['YOB'])
#-------------------------------------->
df['Marital Status'].value_counts()
df['Marital Status'].unique()
h_ms=sns.histplot(df['Marital Status'])
#-------------------------------------->
df['Activity'].unique()
df['Activity'].value_counts()
h_a=sns.histplot(df['Activity'])
#-------------------------------------->
df['Budget'].unique()
df['Budget'].value_counts()
h_b=sns.histplot(df['Budget'])
#------------------------------------->
#which type of food
df['Cuisines'].unique()
df['Cuisines'].value_counts()
h_c=sns.histplot(df['Cuisines'])
#------------------------------------->
df['Food Rating'].unique()
df['Food Rating'].value_counts()
h_fr=sns.histplot(df['Food Rating'])
#------------------------------------>
df['Service Rating'].unique()
df['Service Rating'].value_counts()
h_sr=sns.histplot(df['Service Rating'])
#------------------------------------>
df['Overall Rating'].unique()
df['Overall Rating'].value_counts()
h_or=sns.histplot(df['Overall Rating'])
#-------------------------------------->
df['Often A S'].unique()
df['Often A S'].value_counts()
h_oas=sns.histplot(df['Often A S'])
#-----------------------------------------------histplot--------------------------------->
b_or=sns.boxplot(df['Overall Rating'])
df['Overall Rating'].value_counts()
b_sr=sns.boxplot(df['Service Rating'])
df['Service Rating'].value_counts()
b_fr=sns.boxplot(df['Food Rating'])
df['Food Rating'].value_counts()
b_b=sns.boxplot(df['Budget'])
df['Budget'].value_counts()
b_yob=sns.boxplot(df['YOB'])
df['YOB'].value_counts()
b_ac=sns.boxplot(df['Area code'])
df['Area code'].value_counts()
#---------------------------------------boxplot---------------------->
#df['Location'],df['Gender'],df['YOB'],df['Marital Status']
#df['Activity'],df['Budget'],df['Cuisines'],df['Often A S']
#df['Overall Rating']
#----
sc_l_or=sns.scatterplot(y=df['Location'],x=df['Overall Rating'],data=df,hue='Overall Rating')
sc_g_or=sns.scatterplot(x=df['Gender'],y=df['Overall Rating'],data=df,hue='Gender')
sc_yob_or=sns.scatterplot(x=df['YOB'],y=df['Overall Rating'],data=df,hue='YOB')
sc_ms_or=sns.scatterplot(x=df['Marital Status'],y=df['Overall Rating'],data=df,hue='Marital Status')
sc_a_or=sns.scatterplot(x=df['Activity'],y=df['Overall Rating'],data=df,hue='Activity')
sc_b_or=sns.scatterplot(x=df['Budget'],y=df['Overall Rating'],data=df,hue='Budget')
sc_c_or=sns.scatterplot(x=df['Cuisines'],y=df['Overall Rating'],data=df,hue='Cuisines')
sc_oas_or=sns.scatterplot(x=df['Often A S'],y=df['Overall Rating'],data=df,hue='Often A S')
#----------------------------------------------------scatterplot----------------->
#df['Location'],df['Gender'],df['YOB'],df['Marital Status']
#df['Activity'],df['Budget'],df['Cuisines'],df['Often A S']
#df['Overall Rating']

jn_l_or=sns.jointplot(x=df['Overall Rating'],y=df['Location'],data=df)
jn_g_or=sns.jointplot(x=df['Gender'],y=df['Overall Rating'],data=df)
jn_yob_or=sns.jointplot(x=df['YOB'],y=df['Overall Rating'],data=df)
jn_ms_or=sns.jointplot(x=df['Marital Status'],y=df['Overall Rating'],data=df)
jn_a_or=sns.jointplot(x=df['Activity'],y=df['Overall Rating'],data=df)
jn_b_or=sns.jointplot(x=df['Budget'],y=df['Overall Rating'],data=df)
jn_c_or=sns.jointplot(x=df['Cuisines'],y=df['Overall Rating'],data=df)
jn_oas_or=sns.jointplot(x=df['Often A S'],y=df['Overall Rating'],data=df)
#--------------------------------------jointplot---------------------------------->
#df['Location'],df['Gender'],df['YOB'],df['Marital Status']
#df['Activity'],df['Budget'],df['Cuisines'],df['Often A S']
#df['Overall Rating']

vi_l_or=sns.violinplot(x=df['Overall Rating'],y=df['Location'],data=df)
vi_g_or=sns.violinplot(x=df['Gender'],y=df['Overall Rating'],data=df)
vi_yob_or=sns.violinplot(x=df['YOB'],y=df['Overall Rating'],data=df)
vi_ms_or=sns.violinplot(x=df['Marital Status'],y=df['Overall Rating'],data=df)
vi_a_or=sns.violinplot(x=df['Activity'],y=df['Overall Rating'],data=df)
vi_b_or=sns.violinplot(x=df['Budget'],y=df['Overall Rating'],data=df)
vi_c_or=sns.violinplot(x=df['Cuisines'],y=df['Overall Rating'],data=df)
vi_oas_or=sns.violinplot(x=df['Often A S'],y=df['Overall Rating'],data=df)
#----------------------------------------violinplot----------------------------->
pp_total=sns.pairplot(df)
#------------------------------pair plot-------------------------------->
bar_alcohol_or=plt.bar(df['Alcohol '],df['Overall Rating'])
bar_smoker_or=plt.bar(df['Smoker'],df['Overall Rating'])
plt.show()
